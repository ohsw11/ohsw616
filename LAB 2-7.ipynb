# %%
123 * 456
# Out:
# 56088

# %%
1357 + 2468
# Out:
# 3825

# %%
5 ** 4
# Out:
# 625

# %%
10 / 4
# Out:
# 2.5

# %%
10 // 5
# Out:
# 2

# %%
10 % 5
# Out:
# 0

# %%
5 % 2
# Out:
# 1

# %%
2 ** 0.5
# Out:
# 1.4142135623730951

# %%
3 ** 0.5
# Out:
# 1.7320508075688772
